# %%
import cv2
import matplotlib.pyplot as plt

# %%
fibre_images = r'C:\Users\dezos\Documents\Fibres\FibreAnalysis\Data\synth\Val\masks\mask_2023-07-24_19-31-21-247039.png'

image = cv2.imread(fibre_images)  # Load your input image

# %%
# Create a 2x3 grid of subplots
fig, axes = plt.subplots(2, 5, figsize=(15, 10))

# Set individual titles for each column
axes[0, 0].set_title("Title for Column 1")
axes[0, 1].set_title("Title for Column 2")
axes[0, 2].set_title("Title for Column 3")


ax = axes[0,0]
ax.imshow(image)
ax.axis('off')
ax = axes[0,1]
ax.imshow(image)
ax.axis('off')
ax = axes[0,2]
ax.imshow(image)
ax.axis('off')

ax = axes[1,0]
ax.imshow(image)


ax.axis('off')
# Add more plots and titles as necessary for other subplots in the grid

plt.show()
